# %% [markdown]
# ## 1-1 프로그래밍이란 무엇인가?
#
# ![e4e03737bcbfb98c07a04074251d6579_MD5.jpeg](attachment:e4e03737bcbfb98c07a04074251d6579_MD5.jpeg)
#
# - **[pub.dev](https://pub.dev/)사이트는 **Flutter 및 일반 Dart 프로그램을 위한 라이브러리 및 패키지를 포함하는 Dart 프로그래밍 언어용 패키지 관리자**입니다.

# %% [markdown]
# ## 1-2. Flutter란?
#
# ![image.png](attachment:image.png)
# 프레임워크란?
# 프레임워크란 앞서 설명드렸던 라이브러리와 같이 재사용 가능한 코드와 기능의 집합입니다. 프레임워크만의 특징은 어떤 목적(어플리케이션의 개발 등)을 이루기 위해 개발자에게 제공되는 뼈대라는 점입니다. 이를 위해 프레임워크에는 Control Flow가 제공되며 이는 제품이나 서비스 개발을 위한 표준을 제공한다고 볼 수 있습니다.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 다음 이미지는 현재 시중에 널리 쓰이고 있는 모바일 앱 프레임워크를 보여줍니다.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ### **'크로스 플랫폼 어플리케이션'이며, 'UI 프레임워크'**
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
# - 라이브러리 다양성
#     - 지금은 3만개가 넘는 패키지가 pubdev에 올라와 있다.
#     - 하지만 Java 등에 비해서는 패키지 다양성이 떨어짐
# - 업무 효율성
#     - 플러터는 UI와 로직을 모두 코드로 작성 가능(cf. HTML/CSS and Javascript)
#
# #### [종합퀴즈]
# ① 조건의 참/거짓에 따라 분기가 나뉘는 제어구조(Control Flow)는 무엇일까요?
# ② 라이브러리와 프레임워크의 차이점은 무엇인가요?
#
# >① if-else 구문입니다.
# >
# >② 라이브러리는 개발자가 필요한 기능을 가져와 사용할 수 있는 도구 모음이고, 프레임워크는 개발자에게 구조와 규칙을 제공하여 애플리케이션을 개발할 수 있는 플랫폼입니다. 둘 다 재사용 가능한 코드와 기능의 집합이지만, 프레임워크만의 특징은 어떤 목적(어플리케이션의 개발 등)을 이루기 위해 개발자에게 제공되는 뼈대라는 점입니다.

# %% [markdown]
# ## 1-3. Windows 설치
#
# [노트 1] Windows 설치 1
# ---
# 본 노트는 간략한 요약입니다. 자세한 설치 절차는 영상을 따라하며 확인하시길 바랍니다.
#
# Flutter 설치
# ✔️ Flutter를 설치합니다. ([공식 설치 링크](https://docs.flutter.dev/get-started/install/windows))
#
# Git 설치
# ✔️ Git을 설치합니다. ([공식 설치 링크](https://git-scm.com/downloads))
#
# Android Studio를 설치
# - Android Studio를 설치합니다. ([공식 설치 링크](https://developer.android.com/studio/install?gclid=CjwKCAjwp6CkBhB_EiwAlQVyxe49frmt0vzYTOi6k4Y6doyW0kpSdk7y8sCQfC4t37llLlcb-gw5-RoCyKYQAvD_BwE&gclsrc=aw.ds&hl=ko))
# - Android Studio의 Plugins탭에서 Flutter를 설치합니다.
# - More Actions - SDK Manager에서 SDK Tools 중 'Android SDK Command-line Tools'를 설치합니다.
# - More Actions - Virtual Device Manager에서 Create Device를 눌러 Virtual Device를 하나 추가합니다. 최신 버전으로 선택하면 됩니다.
#
# > AMD CPU를 쓴다면 BIOS에서 SVM Mode Enable 시켜야 함.
# > - https://zzangprogrammer.tistory.com/248
# >
# > Device Manager에서 Advanced로 가서 메모리를 4GB로 늘일 것
#
# Visual Studio Code 설치
# ✔️ Visual Studio Code를 설치합니다. ([공식 설치 링크](https://code.visualstudio.com/download))

# %% [markdown]
# [노트 2] Windows 설치 2
# ---
# 본 노트는 간략한 요약입니다. 자세한 설치 절차는 영상을 따라하며 확인하시길 바랍니다.
#
# - 다운로드하고 압축해제한 Flutter 폴더를 영상 안내에 따라 src 폴더 안으로 이동시킵니다.
# - '시스템 환경변수 편집'에서 환경변수 Path에 Flutter의 'bin' 폴더 경로를 추가합니다.
# - 설치 후 명령 프롬프트(CMD)에 'flutter doctor' 명령어를 실행하여 Flutter의 정상 설치 여부를 확인합니다.
#
# >아래와 같은 문구가 나온다면 'cd 'bin' 폴더 경로'(예: cd C:\src\flutter\bin)를 명령 프롬프트에 입력하여 경로를 이동한 후 'flutter doctor' 명령어를 실행해 보세요.
#
# ![image.png](attachment:image.png)
#
# - Visual Studio Code 에서 다음 Extensions를 설치합니다.
#
# > - Dart
# > - Error Lens
# > - Flutter
# > - Flutter Tree
# > - Material Icon Theme
# > - Pubspec Assist
#
#
# - Flutter: New Project
# - Flutter: Select Device
# > flutter run

# %% [markdown]
# ## 1-4. MacOS 설치
#
# [노트 1] MacOS 설치 1
# ---
# 본 노트는 간략한 요약입니다. 자세한 설치 절차는 영상을 따라하며 확인하시길 바랍니다.
#
# - Flutter를 설치합니다. ([공식 설치 링크](https://docs.flutter.dev/get-started/install/macos))
# - 영상의 안내에 따라 환경변수(PATH Variable)를 업데이트합니다.
# - Homebrew를 설치합니다. ([공식 설치 링크](https://brew.sh/index_ko))
# - cocoapods를 설치합니다. ([공식 설치 링크](https://formulae.brew.sh/formula/cocoapods))
# - Visual Studio Code를 설치합니다. ([공식 설치 링크](https://formulae.brew.sh/cask/visual-studio-code))
# - Android Studio를 설치합니다. ([공식 설치 링크](https://formulae.brew.sh/cask/android-studio))
#
#
# [노트 2] MacOS 설치 2
# ---
# 본 노트는 간략한 요약입니다. 자세한 설치 절차는 영상을 따라하며 확인하시길 바랍니다.
#
# - Xcode를 설치합니다. ([공식 설치 링크](https://apps.apple.com/us/app/xcode/id497799835?mt=12))
# - 터미널(Terminal)에 'flutter doctor' 명령어를 실행하여 Flutter의 정상 설치 여부를 확인합니다.
# - Visual Studio Code 에서 다음 Extensions를 설치합니다.
#
# > - Dart
# > - Error Lens
# > - Flutter
# > - Flutter Tree
# >-Material Icon Theme
# -Pubspec Assist
